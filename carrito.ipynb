-- %% [markdown]
-- # [carrito]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [carrito]    Script Date: 29/02/2024 8:58:10 p. m. ******/
CREATE DATABASE [carrito]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'carrito', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\carrito.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'carrito_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\carrito_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [carrito] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [carrito].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [carrito] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [carrito] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [carrito] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [carrito] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [carrito] SET ARITHABORT OFF 
GO
ALTER DATABASE [carrito] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [carrito] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [carrito] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [carrito] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [carrito] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [carrito] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [carrito] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [carrito] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [carrito] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [carrito] SET  DISABLE_BROKER 
GO
ALTER DATABASE [carrito] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [carrito] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [carrito] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [carrito] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [carrito] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [carrito] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [carrito] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [carrito] SET RECOVERY FULL 
GO
ALTER DATABASE [carrito] SET  MULTI_USER 
GO
ALTER DATABASE [carrito] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [carrito] SET DB_CHAINING OFF 
GO
ALTER DATABASE [carrito] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [carrito] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [carrito] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [carrito] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'carrito', N'ON'
GO
ALTER DATABASE [carrito] SET QUERY_STORE = ON
GO
ALTER DATABASE [carrito] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Detalles]

-- %%
USE [carrito]
GO

-- %%
/****** Object:  Table [dbo].[Detalles]    Script Date: 29/02/2024 8:58:11 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Detalles](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[id_venta] [int] NOT NULL,
	[id_producto] [int] NOT NULL,
	[cantidad] [int] NOT NULL,
	[precio_u] [int] NOT NULL,
	[estado] [varchar](10) NOT NULL,
 CONSTRAINT [PK__Detalles__3213E83FC356226C] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Productos]

-- %%
/****** Object:  Table [dbo].[Productos]    Script Date: 29/02/2024 8:58:11 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Productos](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[descripcion] [varchar](100) NOT NULL,
	[stock] [int] NOT NULL,
	[id_proveedor] [int] NOT NULL,
	[estado] [varchar](10) NOT NULL,
	[precio] [int] NOT NULL,
	[imagen] [text] NOT NULL,
 CONSTRAINT [PK_Productos] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Proveedores]

-- %%
/****** Object:  Table [dbo].[Proveedores]    Script Date: 29/02/2024 8:58:11 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Proveedores](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[estado] [varchar](10) NOT NULL,
 CONSTRAINT [PK_Proveedores] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 29/02/2024 8:58:11 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre_rol] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Roles] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 29/02/2024 8:58:11 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[apellido] [varchar](50) NOT NULL,
	[usuario] [varchar](50) NOT NULL,
	[contrasenia] [varchar](50) NOT NULL,
	[id_rol] [int] NOT NULL,
	[estado] [varchar](10) NOT NULL,
 CONSTRAINT [PK_Usuarios] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ventas]

-- %%
/****** Object:  Table [dbo].[Ventas]    Script Date: 29/02/2024 8:58:11 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ventas](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[fecha] [date] NOT NULL,
	[id_usuario] [int] NOT NULL,
	[estado] [varchar](10) NOT NULL,
 CONSTRAINT [PK_Ventas] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Detalles]

-- %%
SET IDENTITY_INSERT [dbo].[Detalles] ON 
INSERT [dbo].[Detalles] ([id], [id_venta], [id_producto], [cantidad], [precio_u], [estado]) VALUES (1, 3, 1, 1, 200, N'Activado')
SET IDENTITY_INSERT [dbo].[Detalles] OFF
GO

-- %% [markdown]
-- # [dbo].[Productos]

-- %%
SET IDENTITY_INSERT [dbo].[Productos] ON 
INSERT [dbo].[Productos] ([id], [nombre], [descripcion], [stock], [id_proveedor], [estado], [precio], [imagen]) VALUES (1, N'pantalon', N'pantalon de algodon, verde', 80, 2, N'Activo', 200, N'pantalon')
SET IDENTITY_INSERT [dbo].[Productos] OFF
GO

-- %% [markdown]
-- # [dbo].[Proveedores]

-- %%
SET IDENTITY_INSERT [dbo].[Proveedores] ON 
INSERT [dbo].[Proveedores] ([id], [nombre], [estado]) VALUES (2, N'proveedor1', N'Activado')
SET IDENTITY_INSERT [dbo].[Proveedores] OFF
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
SET IDENTITY_INSERT [dbo].[Roles] ON 
INSERT [dbo].[Roles] ([id], [nombre_rol]) VALUES (1, N'Administrador')
INSERT [dbo].[Roles] ([id], [nombre_rol]) VALUES (2, N'Usuario')
SET IDENTITY_INSERT [dbo].[Roles] OFF
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
SET IDENTITY_INSERT [dbo].[Usuarios] ON 
INSERT [dbo].[Usuarios] ([id], [nombre], [apellido], [usuario], [contrasenia], [id_rol], [estado]) VALUES (1, N'katherin', N'perez', N'adminkathe', N'1234', 1, N'Activo')
INSERT [dbo].[Usuarios] ([id], [nombre], [apellido], [usuario], [contrasenia], [id_rol], [estado]) VALUES (2, N'david', N'parra', N'davidp', N'12345', 2, N'Activo')
SET IDENTITY_INSERT [dbo].[Usuarios] OFF
GO

-- %% [markdown]
-- # [dbo].[Ventas]

-- %%
SET IDENTITY_INSERT [dbo].[Ventas] ON 
INSERT [dbo].[Ventas] ([id], [fecha], [id_usuario], [estado]) VALUES (3, CAST(N'2024-02-29' AS Date), 2, N'Activado')
SET IDENTITY_INSERT [dbo].[Ventas] OFF
GO

-- %% [markdown]
-- # [FK__Detalles__id_pro__44FF419A]

-- %%
ALTER TABLE [dbo].[Detalles]  WITH CHECK ADD  CONSTRAINT [FK__Detalles__id_pro__44FF419A] FOREIGN KEY([id_producto])
REFERENCES [dbo].[Productos] ([id])
GO
ALTER TABLE [dbo].[Detalles] CHECK CONSTRAINT [FK__Detalles__id_pro__44FF419A]
GO

-- %% [markdown]
-- # [FK__Detalles__id_ven__440B1D61]

-- %%
ALTER TABLE [dbo].[Detalles]  WITH CHECK ADD  CONSTRAINT [FK__Detalles__id_ven__440B1D61] FOREIGN KEY([id_venta])
REFERENCES [dbo].[Ventas] ([id])
GO
ALTER TABLE [dbo].[Detalles] CHECK CONSTRAINT [FK__Detalles__id_ven__440B1D61]
GO

-- %% [markdown]
-- # [FK_Productos_Proveedores]

-- %%
ALTER TABLE [dbo].[Productos]  WITH CHECK ADD  CONSTRAINT [FK_Productos_Proveedores] FOREIGN KEY([id_proveedor])
REFERENCES [dbo].[Proveedores] ([id])
GO
ALTER TABLE [dbo].[Productos] CHECK CONSTRAINT [FK_Productos_Proveedores]
GO

-- %% [markdown]
-- # [FK_Usuarios_Roles]

-- %%
ALTER TABLE [dbo].[Usuarios]  WITH CHECK ADD  CONSTRAINT [FK_Usuarios_Roles] FOREIGN KEY([id_rol])
REFERENCES [dbo].[Roles] ([id])
GO
ALTER TABLE [dbo].[Usuarios] CHECK CONSTRAINT [FK_Usuarios_Roles]
GO

-- %% [markdown]
-- # [FK_Ventas_Usuarios]

-- %%
ALTER TABLE [dbo].[Ventas]  WITH CHECK ADD  CONSTRAINT [FK_Ventas_Usuarios] FOREIGN KEY([id_usuario])
REFERENCES [dbo].[Usuarios] ([id])
GO
ALTER TABLE [dbo].[Ventas] CHECK CONSTRAINT [FK_Ventas_Usuarios]
GO

-- %% [markdown]
-- # [carrito]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [carrito] SET  READ_WRITE 
GO
